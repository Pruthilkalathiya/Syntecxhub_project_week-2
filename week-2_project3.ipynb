# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dates = pd.date_range(start="2024-01-01", periods=90, freq="D")
sales = np.random.randint(200, 1500, size=90)
categories = (["Electronics", "Clothing", "Groceries"] * 30)[:90]

df = pd.DataFrame({
    "Date": dates,
    "Sales": sales,
    "Category": categories
})

df['Month'] = df['Date'].dt.to_period('M')
df['Quarter'] = df['Date'].dt.quarter

# %%
df_numeric = pd.DataFrame({
    "Sales": df["Sales"],
    "Day": df["Date"].dt.day,
    "Month": df["Date"].dt.month,
    "Quarter": df["Quarter"]
})

df_numeric.head()
# Out:
#    Sales  Day  Month  Quarter
# 0   1252    1      1        1
# 1    969    2      1        1
# 2   1037    3      1        1
# 3    507    4      1        1
# 4    752    5      1        1

# %%
corr = df_numeric.corr()
corr
# Out:
#            Sales     Day    Month  Quarter
# Sales    1.00000 -0.1213 -0.00884      NaN
# Day     -0.12130  1.0000 -0.02410      NaN
# Month   -0.00884 -0.0241  1.00000      NaN
# Quarter      NaN     NaN      NaN      NaN

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="Purples", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.savefig("correlation_heatmap.png")
plt.show()

# %%
sns.pairplot(df_numeric)
plt.savefig("pairplot.png")
plt.show()
